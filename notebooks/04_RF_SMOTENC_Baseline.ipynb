# %%
import sys
sys.path.append("/Users/nedim/Desktop/MY_REPOS/mids-w207-section1-team1-finalproject/src")

# Force reload
from importlib import reload
import data_prep
import modeling

reload(data_prep)
reload(modeling)
# Out:
# 2025-12-08 16:40:10.998526: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <module 'modeling' from '/Users/nedim/Desktop/MY_REPOS/mids-w207-section1-team1-finalproject/src/modeling.py'>

# %%
# mports
from data_prep import load_and_prepare_data
from modeling import train_random_forest, evaluate_random_forest

# %%
# Path
csv_path = "../data/external/FPA_FOD_Plus.csv"

# %%
SMOTE_OPTION = "smotenc"

print(f"Loading and preparing data (SMOTE: {SMOTE_OPTION}) ...")
X_train_final, Y_train_resampled, X_val_final, Y_val, X_test_final, Y_test = load_and_prepare_data(
    csv_path,
    smote_strategy=SMOTE_OPTION
)

print("\nData Shapes:")
print("X_train_final:", X_train_final.shape)
print("Y_train_resampled:", Y_train_resampled.shape)
print("X_val_final:", X_val_final.shape)
print("Y_val:", Y_val.shape)
# Out:
# Loading and preparing data (SMOTE: smotenc) ...
#
# Loading data with Polars...
# File loaded into Pandas. Shape: (2302521, 308)
#
# Pre-Sampling before SMOTENC (500k small class)...
#
# Original class distribution:
# target
# 0    1345082
# 1      33560
# 2       2210
# 3        660
# Name: count, dtype: int64
#
# Pre-sampled total rows: 536,430
#
# Applying SMOTENC oversampling
#
# Data Shapes:
# X_train_final: (2000000, 49)
# Y_train_resampled: (2000000,)
# X_val_final: (460504, 49)
# Y_val: (460504,)

# %%
# Random Forest Training
print("\nTraining Random Forest Model...\n")
rf_model = train_random_forest(
    X_train=X_train_final,
    y_train=Y_train_resampled,
    n_estimators=50,
    random_state=42
)
# Out:
# Training Random Forest Model...

# %%
# Validation Evaluation
print("\nEvaluating on Validation Set...")
evaluate_random_forest(
    model=rf_model,
    X_val=X_val_final,
    y_val=Y_val
)
# Out:
# Evaluating on Validation Set...
#
# Random Forest Validation Accuracy: 0.9219507322411966
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96    448361
#            1       0.12      0.34      0.18     11185
#            2       0.05      0.06      0.05       738
#            3       0.08      0.08      0.08       220
#
#     accuracy                           0.92    460504
#    macro avg       0.31      0.35      0.32    460504
# weighted avg       0.96      0.92      0.94    460504
#
#
# Confusion Matrix:
#  [[420659  26938    630    134]
#  [  7159   3843    139     44]
#  [   309    357     43     29]
#  [    82    106     15     17]]
# array([0, 0, 0, ..., 0, 0, 0])
