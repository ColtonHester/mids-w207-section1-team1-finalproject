# %%
# libraries
import polars as pl
import urllib.request
import os
from pathlib import Path
from datetime import datetime, timedelta

# %%
# current working directory
notebook_dir = Path.cwd()

# go up one level (from notebooks/ → project root), then to data/external
file_path = notebook_dir.parent / "data" / "external" / "FPA_FOD_Plus.csv"

print("File path:", file_path)

df = pl.scan_csv(
    file_path,
    infer_schema_length=10000,  # <- increase this for better type inference
    ignore_errors=True
)
df_full = df.collect()

print(df_full.shape)
# Out:
# File path: /Users/nedim/Desktop/MY_REPOS/mids-w207-section1-team1-finalproject/data/external/FPA_FOD_Plus.csv
# (2302521, 308)

# %% [markdown]
# **Basic Info about the dataset**

# %%
# shape of the dataset
print("Rows:", df_full.height, "Columns:", df_full.width)
# Out:
# Rows: 2302521 Columns: 308

# %%
# preview data
print(df.head(5))
# Out:
# naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# SLICE[offset: 0, len: 5]
#   Csv SCAN [/Users/nedim/Desktop/MY_REPOS/mids-w207-section1-team1-finalproject/data/external/FPA_FOD_Plus.csv]
#   PROJECT */308 COLUMNS

# %%
missing_summary = (
    df_full.select([
        pl.col(col).is_null().sum().alias(col)
        for col in df_full.columns
    ])
)

print("Missing values per column:")
print(missing_summary.transpose(include_header=True))
# Out:
# Missing values per column:
# shape: (308, 2)
# ┌───────────────────────┬──────────┐
# │ column                ┆ column_0 │
# │ ---                   ┆ ---      │
# │ str                   ┆ u32      │
# ╞═══════════════════════╪══════════╡
# │ FOD_ID                ┆ 0        │
# │ FPA_ID                ┆ 0        │
# │ SOURCE_SYSTEM_TYPE    ┆ 0        │
# │ SOURCE_SYSTEM         ┆ 0        │
# │ NWCG_REPORTING_AGENCY ┆ 0        │
# │ …                     ┆ …        │
# │ CheatGrass            ┆ 1921616  │
# │ ExoticAnnualGrass     ┆ 1921616  │
# │ Medusahead            ┆ 1921616  │
# │ PoaSecunda            ┆ 1921616  │
# │ geometry              ┆ 1730504  │
# └───────────────────────┴──────────┘

# %%
print("Column dtypes:")
print(df_full.schema)
# Out:
# Column dtypes:
# Schema([('FOD_ID', Int64), ('FPA_ID', String), ('SOURCE_SYSTEM_TYPE', String), ('SOURCE_SYSTEM', String), ('NWCG_REPORTING_AGENCY', String), ('NWCG_REPORTING_UNIT_ID', String), ('NWCG_REPORTING_UNIT_NAME', String), ('SOURCE_REPORTING_UNIT', String), ('SOURCE_REPORTING_UNIT_NAME', String), ('LOCAL_FIRE_REPORT_ID', Float64), ('LOCAL_INCIDENT_ID', String), ('FIRE_CODE', String), ('FIRE_NAME', String), ('ICS_209_PLUS_INCIDENT_JOIN_ID', String), ('ICS_209_PLUS_COMPLEX_JOIN_ID', String), ('MTBS_ID', String), ('MTBS_FIRE_NAME', String), ('COMPLEX_NAME', String), ('FIRE_YEAR', Int64), ('DISCOVERY_DATE', String), ('DISCOVERY_DOY', Int64), ('DISCOVERY_TIME', Float64), ('NWCG_CAUSE_CLASSIFICATION', String), ('NWCG_GENERAL_CAUSE', String), ('NWCG_CAUSE_AGE_CATEGORY', String), ('CONT_DATE', String), ('CONT_DOY', Float64), ('CONT_TIME', Float64), ('FIRE_SIZE', Float64), ('FIRE_SIZE_CLASS', String), ('LATITUDE', Float64), ('LONGITUDE', Float64), ('OWNER_DESCR', String), ('STATE', String), ('COUNTY', String), ('FIPS_CODE', Float64), ('FIPS_NAME', String), ('LatLong_State', String), ('LatLong_County', String), ('NPL', Float64), ('Mang_Type', String), ('Mang_Name', String), ('Des_Tp', String), ('GAP_Sts', Float64), ('GAP_Prity', Float64), ('EVH', Float64), ('EVT', Float64), ('EVH_1km', String), ('EVT_1km', String), ('EVC', Float64), ('EVC_1km', String), ('NAME', String), ('MOD_NDVI_12m', String), ('MOD_EVI_12m', String), ('Land_Cover', Float64), ('Land_Cover_1km', String), ('rpms', Int64), ('rpms_1km', Float64), ('Population', Float64), ('Popo_1km', Float64), ('GACCAbbrev', String), ('GACC_PL', Float64), ('GACC_New fire', Float64), ('GACC_New LF', Int64), ('GACC_Uncont LF', Int64), ('GACC_Type 1 IMTs', Float64), ('GACC_Type 2 IMTs', Float64), ('GACC_NIMO Teams', Float64), ('GACC_Area Command Teams', Float64), ('GACC_Fire Use Teams', Float64), ('GDP', Float64), ('pr_Normal', Float64), ('tmmn_Normal', Float64), ('tmmx_Normal', Float64), ('rmin_Normal', Float64), ('rmax_Normal', Float64), ('sph_Normal', Float64), ('srad_Normal', Float64), ('fm100_Normal', Float64), ('fm1000_Normal', Float64), ('bi_Normal', Float64), ('vpd_Normal', Float64), ('erc_Normal', Float64), ('DF_PFS', Float64), ('AF_PFS', Float64), ('HDF_PFS', Float64), ('DSF_PFS', Float64), ('EBF_PFS', Float64), ('EALR_PFS', Float64), ('EBLR_PFS', Float64), ('EPLR_PFS', Float64), ('HBF_PFS', Float64), ('LLEF_PFS', Float64), ('LIF_PFS', Float64), ('LMI_PFS', Float64), ('MHVF_PFS', Float64), ('PM25F_PFS', Float64), ('HSEF', Float64), ('P100_PFS', Float64), ('P200_PFS', Float64), ('LPF_PFS', Float64), ('NPL_PFS', Float64), ('RMP_PFS', Float64), ('TSDF_PFS', Float64), ('TPF', Float64), ('TF_PFS', Float64), ('UF_PFS', Float64), ('WF_PFS', Float64), ('M_WTR', Float64), ('M_WKFC', Float64), ('M_CLT', Float64), ('M_ENY', Float64), ('M_TRN', Float64), ('M_HSG', Float64), ('M_PLN', Float64), ('M_HLTH', Float64), ('SM_C', Float64), ('SM_PFS', Float64), ('EPLRLI', Float64), ('EALRLI', Float64), ('EBLRLI', Float64), ('PM25LI', Float64), ('EBLI', Float64), ('DPMLI', Float64), ('TPLI', Float64), ('LPMHVLI', Float64), ('HBLI', Float64), ('RMPLI', Float64), ('SFLI', Float64), ('HWLI', Float64), ('WDLI', Float64), ('DLI', Float64), ('ALI', Float64), ('HDLI', Float64), ('LLELI', Float64), ('LILHSE', Float64), ('PLHSE', Float64), ('LMILHSE', Float64), ('ULHSE', Float64), ('EPL_ET', Float64), ('EAL_ET', Float64), ('EBL_ET', Float64), ('EB_ET', Float64), ('PM25_ET', Float64), ('DS_ET', Float64), ('TP_ET', Float64), ('LPP_ET', Float64), ('HB_ET', Float64), ('RMP_ET', Float64), ('NPL_ET', Float64), ('TSDF_ET', Float64), ('WD_ET', Float64), ('DB_ET', Float64), ('A_ET', Float64), ('HD_ET', Float64), ('LLE_ET', Float64), ('UN_ET', Float64), ('LISO_ET', Float64), ('POV_ET', Float64), ('LMI_ET', Float64), ('IA_LMI_ET', Float64), ('IA_UN_ET', Float64), ('IA_POV_ET', Float64), ('TC', Float64), ('CC', Float64), ('IAULHSE', Float64), ('IAPLHSE', Float64), ('IALMILHSE', Float64), ('IALMIL_87', String), ('IAPLHS_88', Strin ...

# %%
print("Summary stats:")
print(df_full.describe())
# Out:
# Summary stats:
# shape: (9, 309)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ FOD_ID    ┆ FPA_ID    ┆ SOURCE_SY ┆ … ┆ ExoticAnn ┆ Medusahea ┆ PoaSecund ┆ geometry │
# │ ---       ┆ ---       ┆ ---       ┆ STEM_TYPE ┆   ┆ ualGrass  ┆ d         ┆ a         ┆ ---      │
# │ str       ┆ f64       ┆ str       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ str      │
# │           ┆           ┆           ┆ str       ┆   ┆ str       ┆ str       ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 2.302521e ┆ 2302521   ┆ 2302521   ┆ … ┆ 380905    ┆ 380905    ┆ 380905    ┆ 572017   │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ null_coun ┆ 0.0       ┆ 0         ┆ 0         ┆ … ┆ 1921616   ┆ 1921616   ┆ 1921616   ┆ 1730504  │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 1.1838e8  ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ std       ┆ 1.6208e8  ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ min       ┆ 1.0       ┆ 2011CAIRS ┆ FED       ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ POINT    │
# │           ┆           ┆ 17126333  ┆           ┆   ┆           ┆           ┆           ┆ (-0.0321 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 60158414 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 602      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1702…    │
# │ 25%       ┆ 622281.0  ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 50%       ┆ 1.403098e ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 75%       ┆ 3.0000627 ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ 7e8       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ max       ┆ 4.0065115 ┆ WI-840922 ┆ NONFED    ┆ … ┆ 9.0       ┆ 9.0       ┆ 9.0       ┆ POINT    │
# │           ┆ 9e8       ┆ 91998     ┆           ┆   ┆           ┆           ┆           ┆ (999996. │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 93567602 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 98       │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 12303…   │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
print(df_full.select(pl.col("STATE").unique().sort()))
# Out:
# shape: (52, 1)
# ┌───────┐
# │ STATE │
# │ ---   │
# │ str   │
# ╞═══════╡
# │ AK    │
# │ AL    │
# │ AR    │
# │ AZ    │
# │ CA    │
# │ …     │
# │ VT    │
# │ WA    │
# │ WI    │
# │ WV    │
# │ WY    │
# └───────┘

# %%
# checking for any dupe fires
dupes = df_full.select(pl.col("FOD_ID")).is_duplicated().sum()
print("Duplicate FOD_IDs:", dupes)
# Out:
# Duplicate FOD_IDs: 128

# %%
df_full.columns
# Out:
# ['FOD_ID',
#  'FPA_ID',
#  'SOURCE_SYSTEM_TYPE',
#  'SOURCE_SYSTEM',
#  'NWCG_REPORTING_AGENCY',
#  'NWCG_REPORTING_UNIT_ID',
#  'NWCG_REPORTING_UNIT_NAME',
#  'SOURCE_REPORTING_UNIT',
#  'SOURCE_REPORTING_UNIT_NAME',
#  'LOCAL_FIRE_REPORT_ID',
#  'LOCAL_INCIDENT_ID',
#  'FIRE_CODE',
#  'FIRE_NAME',
#  'ICS_209_PLUS_INCIDENT_JOIN_ID',
#  'ICS_209_PLUS_COMPLEX_JOIN_ID',
#  'MTBS_ID',
#  'MTBS_FIRE_NAME',
#  'COMPLEX_NAME',
#  'FIRE_YEAR',
#  'DISCOVERY_DATE',
#  'DISCOVERY_DOY',
#  'DISCOVERY_TIME',
#  'NWCG_CAUSE_CLASSIFICATION',
#  'NWCG_GENERAL_CAUSE',
#  'NWCG_CAUSE_AGE_CATEGORY',
#  'CONT_DATE',
#  'CONT_DOY',
#  'CONT_TIME',
#  'FIRE_SIZE',
#  'FIRE_SIZE_CLASS',
#  'LATITUDE',
#  'LONGITUDE',
#  'OWNER_DESCR',
#  'STATE',
#  'COUNTY',
#  'FIPS_CODE',
#  'FIPS_NAME',
#  'LatLong_State',
#  'LatLong_County',
#  'NPL',
#  'Mang_Type',
#  'Mang_Name',
#  'Des_Tp',
#  'GAP_Sts',
#  'GAP_Prity',
#  'EVH',
#  'EVT',
#  'EVH_1km',
#  'EVT_1km',
#  'EVC',
#  'EVC_1km',
#  'NAME',
#  'MOD_NDVI_12m',
#  'MOD_EVI_12m',
#  'Land_Cover',
#  'Land_Cover_1km',
#  'rpms',
#  'rpms_1km',
#  'Population',
#  'Popo_1km',
#  'GACCAbbrev',
#  'GACC_PL',
#  'GACC_New fire',
#  'GACC_New LF',
#  'GACC_Uncont LF',
#  'GACC_Type 1 IMTs',
#  'GACC_Type 2 IMTs',
#  'GACC_NIMO Teams',
#  'GACC_Area Command Teams',
#  'GACC_Fire Use Teams',
#  'GDP',
#  'pr_Normal',
#  'tmmn_Normal',
#  'tmmx_Normal',
#  'rmin_Normal',
#  'rmax_Normal',
#  'sph_Normal',
#  'srad_Normal',
#  'fm100_Normal',
#  'fm1000_Normal',
#  'bi_Normal',
#  'vpd_Normal',
#  'erc_Normal',
#  'DF_PFS',
#  'AF_PFS',
#  'HDF_PFS',
#  'DSF_PFS',
#  'EBF_PFS',
#  'EALR_PFS',
#  'EBLR_PFS',
#  'EPLR_PFS',
#  'HBF_PFS',
#  'LLEF_PFS',
#  'LIF_PFS',
#  'LMI_PFS',
#  'MHVF_PFS',
#  'PM25F_PFS',
#  'HSEF',
#  'P100_PFS',
#  'P200_PFS',
#  'LPF_PFS',
#  'NPL_PFS',
#  'RMP_PFS',
#  'TSDF_PFS',
#  'TPF',
#  'TF_PFS',
#  'UF_PFS',
#  'WF_PFS',
#  'M_WTR',
#  'M_WKFC',
#  'M_CLT',
#  'M_ENY',
#  'M_TRN',
#  'M_HSG',
#  'M_PLN',
#  'M_HLTH',
#  'SM_C',
#  'SM_PFS',
#  'EPLRLI',
#  'EALRLI',
#  'EBLRLI',
#  'PM25LI',
#  'EBLI',
#  'DPMLI',
#  'TPLI',
#  'LPMHVLI',
#  'HBLI',
#  'RMPLI',
#  'SFLI',
#  'HWLI',
#  'WDLI',
#  'DLI',
#  'ALI',
#  'HDLI',
#  'LLELI',
#  'LILHSE',
#  'PLHSE',
#  'LMILHSE',
#  'ULHSE',
#  'EPL_ET',
#  'EAL_ET',
#  'EBL_ET',
#  'EB_ET',
#  'PM25_ET',
#  'DS_ET',
#  'TP_ET',
#  'LPP_ET',
#  'HB_ET',
#  'RMP_ET',
#  'NPL_ET',
#  'TSDF_ET',
#  'WD_ET',
#  'DB_ET',
#  'A_ET',
#  'HD_ET',
#  'LLE_ET',
#  'UN_ET',
#  'LISO_ET',
#  'POV_ET',
#  'LMI_ET',
#  'IA_LMI_ET',
#  'IA_UN_ET',
#  'IA_POV_ET',
#  'TC',
#  'CC',
#  'IAULHSE',
#  'IAPLHSE',
#  'IALMILHSE',
#  'IALMIL_87',
#  'IAPLHS_88',
#  'IAULHS_89',
#  'LHE',
#  'IALHE',
#  'IAHSEF',
#  'CA',
#  'NCA',
#  'CA_LT20',
#  'M_CLT_EOMI',
#  'M_ENY_EOMI',
#  'M_TRN_EOMI',
#  'M_HSG_EOMI',
#  'M_PLN_EOMI',
#  'M_WTR_EOMI',
#  'M_HLTH_102',
#  'M_WKFC_103',
#  'FPL200S',
#  'M_WKFC_105',
#  'M_EBSI',
#  'UI_EXP',
#  'THRHLD',
#  'No_FireStation_1.0km',
#  'No_FireStation_5.0km',
#  'No_FireStation_10.0km',
#  'No_FireStation_20.0km',
#  'FRG_1km',
#  'FRG',
#  'TRI_1km',
#  'TRI',
#  'Aspect_1km',
#  'Elevation_1km',
#  'Elevation',
#  'Slope_1km',
#  'Aspect',
#  'Slope',
#  'GHM',
#  'TPI',
#  'TPI_1km',
#  'TRACT',
#  'RPL_THEMES',
#  'RPL_THEME1',
#  'EPL_POV',
#  'EPL_UNEMP',
#  'EPL_PCI',
#  'EPL_NOHSDP',
#  'RPL_THEME2',
#  'EPL_AGE65',
#  'EPL_AGE17',
#  'EPL_DISABL',
#  'EPL_SNGPNT',
#  'RPL_THEME3',
#  'EPL_MINRTY',
#  'EPL_LIMENG',
#  'RPL_THEME4',
#  'EPL_MUNIT',
#  'EPL_MOBILE',
#  'EPL_CROWD',
#  'EPL_NOVEH',
#  'EPL_GROUPQ',
#  'road_county_dis',
#  'road_interstate_dis',
#  'road_common_name_dis',
#  'road_other_dis',
#  'road_state_dis',
#  'road_US_dis',
#  'Ecoregion_US_L4CODE',
#  'Ecoregion_US_L3CODE',
#  'Ecoregion_NA_L3CODE',
#  'Ecoregion_NA_L2CODE',
#  'Ecoregion_NA_L1CODE',
#  'SDI',
#  'Annual_etr',
#  'Annual_precipitation',
#  'Annual_tempreture',
#  'Aridity_index',
#  'Evacuation',
#  'pr',
#  'tmmn',
#  'tmmx',
#  'rmin',
#  'rmax',
#  'sph',
#  'vs',
#  'th',
#  'srad',
#  'etr',
#  'fm100',
#  'fm1000',
#  'bi',
#  'vpd',
#  'erc',
#  'pr_5D_mean',
#  'tmmn_5D_mean',
#  'tmmx_5D_mean',
#  'rmin_5D_mean',
#  'rmax_5D_mean',
#  'sph_5D_mean',
#  'vs_5D_mean',
#  'th_5D_mean',
#  'srad_5D_mean',
#  'etr_5D_mean',
#  'fm100_5D_mean',
#  'fm1000_5D_mean',
#  'bi_5D_mean',
#  'vpd_5D_mean',
#  'erc_5D_mean',
#  'pr_5D_min',
#  'pr_5D_max',
#  'tmmn_5D_max',
#  'tmmx_5D_max',
#  'rmin_5D_min',
#  'rmax_5D_min',
#  'sph_5D_min',
#  'vs_5D_max',
#  'th_5D_max',
#  'srad_5D_max',
#  'etr_5D_max',
#  'fm100_5D_min',
#  'fm1000_5D_min',
#  'bi_5D_max',
#  'vpd_5D_max',
#  'erc_5D_max',
#  'tmmn_Percentile',
#  'tmmx_Percentile',
#  'sph_Percentile',
#  'vs_Percentile',
#  'fm100_Percentile',
#  'bi_Percentile',
#  'vpd_Percentile',
#  'erc_Percentile',
#  'NDVI-1day',
#  'NDVI_min',
#  'NDVI_max',
#  'NDVI_mean',
#  'CheatGrass',
#  'ExoticAnnualGrass',
#  'Medusahead',
#  'PoaSecunda',
#  'geometry']

# %%
date_range = df_full.select(
    pl.col("DISCOVERY_DATE").min().alias("DISCOVERY_DATE_min"),
    pl.col("DISCOVERY_DATE").max().alias("DISCOVERY_DATE_max")
)

print(date_range)
# Out:
# shape: (1, 2)
# ┌────────────────────┬────────────────────┐
# │ DISCOVERY_DATE_min ┆ DISCOVERY_DATE_max │
# │ ---                ┆ ---                │
# │ str                ┆ str                │
# ╞════════════════════╪════════════════════╡
# │ 1992-01-01         ┆ 2020-12-31         │
# └────────────────────┴────────────────────┘

# %%
# convert to datetime format for future analysis
# only using df from this point on
df = df_full.with_columns(
    pl.col("DISCOVERY_DATE").str.strptime(pl.Date, "%Y-%m-%d").alias("DISCOVERY_DATE")
)

print(df.select("DISCOVERY_DATE").head())
# Out:
# shape: (5, 1)
# ┌────────────────┐
# │ DISCOVERY_DATE │
# │ ---            │
# │ date           │
# ╞════════════════╡
# │ 2007-01-01     │
# │ 2007-01-01     │
# │ 2007-01-01     │
# │ 2007-01-01     │
# │ 2007-01-01     │
# └────────────────┘

# %%
# count how many missing values in DISCOVERY_DATE
missing_count = df.select(
    pl.col("DISCOVERY_DATE").is_null().sum().alias("missing_dates")
)

print(missing_count)
# Out:
# shape: (1, 1)
# ┌───────────────┐
# │ missing_dates │
# │ ---           │
# │ u32           │
# ╞═══════════════╡
# │ 0             │
# └───────────────┘
